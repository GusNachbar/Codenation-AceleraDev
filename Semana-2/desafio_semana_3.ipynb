# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('desafio1.csv')

# %%
df.head(5)
# Out:
#    RowNumber                                        id  \
# 0          1  e7f44fcbd380d4cef7e6c232cc7e37895c3fd197
# 1          2  28dcb083ad90512da16b9430085c2cddb8ca5e12
# 2          3  774bc378f787438c9c7594e536787d07a097a54b
# 3          4  043a71326f7096de155e7f0c559dc62b5e4b7239
# 4          5  37b3bb8ca243955fb3605ec7e1c2a4607cdb3b22
#
#                                   sobrenome  pontuacao_credito  \
# 0  6d6e0aa1b9b413e442e2fb68df14b4fc3f91de50                619
# 1  48e1ad846796fa314f1b4a6702b83343eb5482c5                608
# 2  f2b29d5d934de615812b697132e767dea0f1e9e2                502
# 3  85d5c9da7cddd8109ad32a6c348fe2bb10bf99f2                699
# 4  ddc89c837a6933639de75f28171057060bd322df                850
#
#   estado_residencia genero  idade  nivel_estabilidade  saldo_conta  \
# 0                SC      F     42                   2         0.00
# 1                RS      F     41                   1     83807.86
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 12 columns):
# RowNumber                   7000 non-null int64
# id                          7000 non-null object
# sobrenome                   7000 non-null object
# pontuacao_credito           7000 non-null int64
# estado_residencia           7000 non-null object
# genero                      7000 non-null object
# idade                       7000 non-null int64
# nivel_estabilidade          7000 non-null int64
# saldo_conta                 7000 non-null float64
# numero_produtos             7000 non-null int64
# possui_cartao_de_credito    7000 non-null int64
# membro_ativo                7000 non-null int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 656.3+ KB

# %%
df['estado_residencia'].describe()
# Out:
# count     7000
# unique       3
# top         SC
# freq      3519
# Name: estado_residencia, dtype: object

# %%
df_sc = df[df['estado_residencia'] == 'SC']

# %%
df_sc
# Out:
#       RowNumber                                        id  \
# 0             1  e7f44fcbd380d4cef7e6c232cc7e37895c3fd197
# 2             3  774bc378f787438c9c7594e536787d07a097a54b
# 3             4  043a71326f7096de155e7f0c559dc62b5e4b7239
# 6             7  8f3cc64a0a84bab38fefb030f09757d0cbf03bb2
# 8             9  35f41954a87f722a3960e5fa8ce898a09398a564
# 9            10  f110be36fc6171a7da472b9cbac8698df880aac6
# 10           11  616ab70b0c6c9bbca2053d3841890a9831c5e547
# 12           13  09470d0412441f628088863770edd8203a6d061a
# 13           14  572eae7cd6575a5b53f64a86086b145e7166c627
# 19           20  5d4168b50ccd45013fe0825674c62e88bdc4bc7c
# 20           21  126b4161a90e5111ed65761b48245f4e7f49141f
# 23           24  8ad90a634410dff2c8c95664c397d574668f8c15
# 24           25  3d663c528596602e01a61269591b85a5f807758a
# 25           26  3e3b037e09aaaf96e4db397c1ee4e7c88aae0d2b
# 27           28  37282c1c850a72ed07c506e6c3daf51412aabb7d
# ...

# %%
mean_sc = df_sc['pontuacao_credito'].mean()
median_sc = df_sc['pontuacao_credito'].median()
mode_sc = df_sc['pontuacao_credito'].mode()
std_sc = df_sc['pontuacao_credito'].std()

# %%
mean_sc
# Out:
# 649.5376527422563

# %%
median_sc
# Out:
# 653.0

# %%
mode_sc
# Out:
# 0    850
# dtype: int64

# %%
std_sc
# Out:
# 97.23349279343306

# %%
df_sc.describe()
# Out:
#          RowNumber  pontuacao_credito        idade  nivel_estabilidade  \
# count  3519.000000        3519.000000  3519.000000         3519.000000
# mean   3540.096334         649.537653    38.482523            4.999147
# std    2011.598038          97.233493    10.438165            2.892670
# min       1.000000         359.000000    18.000000            0.000000
# 25%    1810.500000         581.000000    31.000000            2.000000
# 50%    3521.000000         653.000000    37.000000            5.000000
# 75%    5271.000000         717.000000    43.000000            7.000000
# max    7000.000000         850.000000    92.000000           10.000000
#
#          saldo_conta  numero_produtos  possui_cartao_de_credito  membro_ativo
# count    3519.000000      3519.000000               3519.000000   3519.000000
# mean    62439.046206         1.525718                  0.707019      0.512930
# std     64304.799912         0.571102                  0.455194      0.499904
# ...

# %%
df_pr = df[df['estado_residencia'] == 'PR']

# %%
df_pr
# Out:
#       RowNumber                                        id  \
# 7             8  6704b822c203e2dda9f225dfc4f1bed2ae9044e6
# 15           16  04a488f5afe23bc8e0bc2dab36b7ef31a2175465
# 16           17  5970b1f277e0c09c2fbdf5c0b2961e286d1eee8a
# 26           27  93f9d14870d4e1f4b406e822aeda2522034e36a7
# 28           29  29696d097f5af397971553e03af3d72544a2de43
# 32           33  80121ca72032240577824fdd8fba3757a337c41a
# 39           40  86dd03103e33d8505f948894162dcd1a1d6975ff
# 45           46  bb42d240534ef8b417e52f730737bc303bd0fc72
# 46           47  cf88ac17b29073b62e32fc49efefad3a9e05978b
# 47           48  7f59a95708fae4971f00a8370d54cc4d7475ff67
# 48           49  b22818e3a916c580f5c4e71d68d374d25b3476f9
# 49           50  f28292dbeb8b788d4299150fa4527bc57d6418b6
# 50           51  818d8df02268036710170fd9827d99d5f2923c29
# 51           52  7a78998ddaa89269f317fad715f7dc68a671558e
# 53           54  ea80e44a620379e2cfefd015735dc2235f3a364d
# ...

# %%
mean_pr = df_pr['pontuacao_credito'].mean()
median_pr = df_pr['pontuacao_credito'].median()
mode_pr = df_pr['pontuacao_credito'].mode()
std_pr = df_pr['pontuacao_credito'].std()

# %%
mean_pr
# Out:
# 648.9612940496822

# %%
median_pr
# Out:
# 650.0

# %%
mode_pr[0]
# Out:
# 850

# %%
std_pr
# Out:
# 98.60718591309772

# %%
df_rs = df[df['estado_residencia'] == 'RS']

# %%
mean_rs = df_rs['pontuacao_credito'].mean()
median_rs = df_rs['pontuacao_credito'].median()
mode_rs = df_rs['pontuacao_credito'].mode()
std_rs = df_rs['pontuacao_credito'].std()

# %%
mean_rs
# Out:
# 651.1051428571428

# %%
median_rs
# Out:
# 650.0

# %%
mode_rs
# Out:
# 0    850
# dtype: int64

# %%
std_rs
# Out:
# 95.1365984138357

# %%
df_answer = pd.DataFrame({'estado': ['SC', 'PR', 'RS'], 'media': [mean_sc, mean_pr, mean_rs], 'mediana' : [median_sc, median_pr, median_rs], 'moda': [mode_sc[0], mode_pr[0], mode_rs[0]], 'desvio_padrao': [std_sc, std_pr, std_rs]})

# %%
df_answer.set_index('estado', inplace=True)

# %%
df_answer
# Out:
#              media  mediana  moda  desvio_padrao
# estado
# SC      649.537653    653.0   850      97.233493
# PR      648.961294    650.0   850      98.607186
# RS      651.105143    650.0   850      95.136598

# %%
df_answer = df_answer.T

# %%
df_answer
# Out:
# estado                 SC          PR          RS
# media          649.537653  648.961294  651.105143
# mediana        653.000000  650.000000  650.000000
# moda           850.000000  850.000000  850.000000
# desvio_padrao   97.233493   98.607186   95.136598

# %%
df_answer.to_json('submission.json')
