# %% [markdown]
# # Desafio 4
#
# Neste desafio, vamos praticar um pouco sobre testes de hipóteses. Utilizaremos o _data set_ [2016 Olympics in Rio de Janeiro](https://www.kaggle.com/rio2016/olympic-games/), que contém dados sobre os atletas das Olimpíadas de 2016 no Rio de Janeiro.
#
# Esse _data set_ conta com informações gerais sobre 11538 atletas como nome, nacionalidade, altura, peso e esporte praticado. Estaremos especialmente interessados nas variáveis numéricas altura (`height`) e peso (`weight`). As análises feitas aqui são parte de uma Análise Exploratória de Dados (EDA).
#
# > Obs.: Por favor, não modifique o nome das funções de resposta.

# %% [markdown]
# ## _Setup_ geral

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sct
import statsmodels.api as sm
import seaborn as sns

# %%
#%matplotlib inline

from IPython.core.pylabtools import figsize


figsize(12, 8)

sns.set()

# %%
athletes = pd.read_csv("athletes.csv")

# %%
def get_sample(df, col_name, n=100, seed=42):
    """Get a sample from a column of a dataframe.
    
    It drops any numpy.nan entries before sampling. The sampling
    is performed without replacement.
    
    Example of numpydoc for those who haven't seen yet.
    
    Parameters
    ----------
    df : pandas.DataFrame
        Source dataframe.
    col_name : str
        Name of the column to be sampled.
    n : int
        Sample size. Default is 100.
    seed : int
        Random seed. Default is 42.
    
    Returns
    -------
    pandas.Series
        Sample of size n from dataframe's column.
    """
    np.random.seed(seed)
    
    random_idx = np.random.choice(df[col_name].dropna().index, size=n, replace=False)
    
    return df.loc[random_idx, col_name]

# %% [markdown]
# ## Inicia sua análise a partir daqui

# %%
# Sua análise começa aqui.
athletes.head(5)
# Out:
#           id            name nationality     sex       dob  height  weight  \
# 0  736041664  A Jesus Garcia         ESP    male  10/17/69    1.72    64.0
# 1  532037425      A Lam Shin         KOR  female   9/23/86    1.68    56.0
# 2  435962603     Aaron Brown         CAN    male   5/27/92    1.98    79.0
# 3  521041435      Aaron Cook         MDA    male    1/2/91    1.83    80.0
# 4   33922579      Aaron Gate         NZL    male  11/26/90    1.81    71.0
#
#        sport  gold  silver  bronze
# 0  athletics     0       0       0
# 1    fencing     0       0       0
# 2  athletics     0       0       1
# 3  taekwondo     0       0       0
# 4    cycling     0       0       0

# %%
athletes.describe()
# Out:
#                  id        height        weight          gold        silver  \
# count  1.153800e+04  11208.000000  10879.000000  11538.000000  11538.000000
# mean   4.999885e+08      1.766282     72.068205      0.057722      0.056769
# std    2.908648e+08      0.112719     16.177334      0.255910      0.239147
# min    1.834700e+04      1.210000     31.000000      0.000000      0.000000
# 25%    2.450997e+08      1.690000     60.000000      0.000000      0.000000
# 50%    5.002011e+08      1.760000     70.000000      0.000000      0.000000
# 75%    7.539874e+08      1.840000     81.000000      0.000000      0.000000
# max    9.999878e+08      2.210000    170.000000      5.000000      2.000000
#
#              bronze
# count  11538.000000
# mean       0.061016
# std        0.243320
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        2.000000

# %%
altura = get_sample(athletes,['height'], n=3000)
altura
# Out:
#        height
# 1811     1.79
# 7962     1.81
# 10280    1.83
# 317      1.68
# 6989     2.01
# 7975     2.02
# 4430     1.78
# 7293     1.57
# 2248     1.59
# 5109     1.82
# 9053     1.68
# 8945     1.51
# 9452     1.78
# 10366    1.65
# 4223     1.81
# 9513     1.65
# 7616     1.59
# 7269     1.70
# 3684     1.63
# 6142     1.65
# 6578     1.76
# 4683     1.73
# 2170     1.88
# 7607     1.86
# 11358    1.77
# 1770     1.96
# 4576     1.96
# 9093     1.88
# 2082     1.82
# 9901     1.74
# ...       ...
# 1662     1.98
# 2813     1.85
# 6692     1.63
# 3073     1.90
# 10716    1.87
# 673      1.74
# 2943     1.78
# 911      1.60
# 5582     1.79
# 2369     1.75
# 9206     1.58
# 1674     1.75
# 572      1.63
# 10434    1.83
# 8680     1.78
# 8662     1.87
# 9420     1.70
# 3630     1.88
# 5503     1.76
# 223      1.68
# 9712     1.80
# 11022    1.93
# 9269     1.65
# 9818     1.70
# 75       2.03
# 1483     1.75
# 2586     1.78
# 2949     1.60
# 10268    1.75
# 5892     1.76
#
# [3000 rows x 1 columns]

# %%
peso = get_sample(athletes, ['weight'], n=3000)
log_peso = np.log(peso)

# %%
bra = athletes[athletes['nationality'] == 'BRA']
bra
# Out:
#               id                        name nationality     sex       dob  \
# 79     236523132                   Adam Imer         BRA    male   8/18/89
# 106    993710181           Adenizia da Silva         BRA  female  12/18/86
# 109    930618704            Adilson da Silva         BRA    male   1/24/72
# 114    787208883               Adrian Baches         BRA    male    4/7/90
# 128     80367651  Adriana Aparecida da Silva         BRA  female   7/22/81
# 129    593328448              Adriana Araujo         BRA  female   11/4/81
# 132    529241363              Adriana Moises         BRA  female   12/6/78
# 145     28097741           Agatha Bednarczuk         BRA  female   6/22/83
# 284     74286490     Aldemir da Silva Junior         BRA    male    6/8/92
# 355    566695148                 Alex Garcia         BRA    male    3/4/80
# 367    703205900    Alex William Pombo Silva         BRA    male   7/21/88
# 396    658069337             Alexander Russo         BRA    male   7/26/94
# 412     30769207          Alexandra Martinez         BRA  female   9/16/81
# 427    333303277           Alexandre Camargo         BRA    male   4/25/99
# 433     17092453            Alexandro Pozzer         BRA    male  12/21/88
# 508    315643745                       Aline         BRA  female   4/15/89
# 510    215286232     Aline da Silva Ferreira         BRA  female  10/18/86
# 518    409870387              Alison Cerutti         BRA    male   12/7/85
# 532    846754382              Allan do carmo         BRA    male    8/3/89
# 555     46528538           Altobeli da Silva         BRA    male   12/3/90
# 556    344062200      Alvaro Doda de Miranda         BRA    male    2/5/73
# 581    991318461               Amanda Araujo         BRA  female   2/23/90
# 588    936271742             Amanda Oliveira         BRA  female    1/6/87
# 590    362158810               Amanda Simeao         BRA  female    6/2/94
# 647    829962369          Ana Beatriz Bulcao         BRA  female   12/4/93
# 649    714771450           Ana Claudia Silva         BRA  female   11/6/88
# 658    575479562         Ana Luiza Barbachan         BRA  female   8/15/89
# 660     69147633           Ana Marcela Cunha         BRA  female   3/23/92
# 663    453790004              Ana Paula Belo         BRA  female  10/18/87
# 664    724211622           Ana Paula Vergutz         BRA  female   4/20/89
# ...          ...                         ...         ...     ...       ...
# 10457  831910280             Thomaz Bellucci         BRA    male  12/30/87
# 10465  850164905                Tiago Camilo         BRA    male   5/24/82
# 10675  662685854                      Uilson         BRA    male   4/28/94
# 10709  723818458         Vagner Junior Souta         BRA    male   2/10/91
# 10715  839835613                    Valdivia         BRA    male   10/4/94
# 10749  287472239              Vanessa Chefer         BRA  female    3/5/90
# 10750   87607313               Vanessa Cozzi         BRA  female   3/25/84
# 10778  967486655           Venilton Teixeira         BRA    male    9/6/95
# 10813  706996244             Victor Penalber         BRA    male   5/22/90
# 10816  810144612           Victoria Chamorro         BRA  female   7/10/96
# 10822  904905925           Victoria Lovelady         BRA  female  11/29/86
# 10879  253097119          Vinicius Antonelli         BRA    male    3/1/90
# 10880   29581250           Vinicius Teixeira         BRA    male    4/3/88
# 10898  411101006                Vitor Benite         BRA    male   2/20/90
# 10899  987131879       Vitor Hugo dos Santos         BRA    male    2/1/96
# 10900  623036229       Vitoria Cristina Rosa         BRA  female   1/12/96
# 10905  110185191               Viviane Bahia         BRA  female   2/14/94
# 10941  754088322             Wagner Domingos         BRA    male   3/26/83
# 10944  419317871                      Walace         BRA    male    4/4/95
# 10948  344970215            Wallace de Souza         BRA    male   6/26/87
# 10972  114920742      Welisson Rosa da Silva         BRA    male  11/22/83
# 10992  455850470                    Weverton         BRA    male  12/13/87
# 11010  550290516                     William         BRA    male    4/3/95
# 11011  624517317              William Arjona         BRA    male   7/31/79
# 11021  925824275           Willian Giaretton         BRA    male   9/26/90
# 11052    9403852           Xavier Vela Maggi         BRA    male    8/7/89
# 11136  599927932         Yane Marcia Marques         BRA  female    1/7/84
# 11228  586074732     Ygor Coelho de Oliveira         BRA    male  11/24/96
# 11404  409923311        Yuri van der Heijden         BRA    male   7/20/90
# 11457  879954351                        Zeca         BRA    male   5/16/94
#
#        height  weight              sport  gold  silver  bronze
# 79       1.82    88.0             hockey     0       0       0
# 106      1.87    65.0         volleyball     0       0       0
# 109      1.70    79.0               golf     0       0       0
# 114      1.84    83.0           aquatics     0       0       0
# 128      1.66    52.0          athletics     0       0       0
# 129      1.67     NaN             boxing     0       0       0
# 132      1.70    65.0         basketball     0       0       0
# 145      1.82    70.0         volleyball     0       1       0
# 284      1.93    80.0          athletics     0       0       0
# 355      1.92   102.0         basketball     0       0       0
# 367      1.74    73.0               judo     0       0       0
# 396      1.73    61.0          athletics     0       0       0
# 412      1.77    68.0           handball     0       0       0
# 427      1.77    75.0            fencing     0       0       0
# 433      1.92   107.0           handball     0       0       0
# 508      1.62    60.0           football     0       0       0
# 510      1.78    80.0          wrestling     0       0       0
# 518      2.03   102.0         volleyball     1       0       0
# 532      1.74    73.0           aquatics     0       0       0
# 555      1.81    60.0          athletics     0       0       0
# 556      1.86    86.0         equestrian     0       0       0
# 581      1.62    54.0       rugby sevens     0       0       0
# 588      1.69    58.0           aquatics     0       0       0
# 590      1.66    62.0            fencing     0       0       0
# 647      1.67    58.0            fencing     0       0       0
# 649      1.58    56.0          athletics     0       0       0
# 658      1.71    68.0            sailing     0       0       0
# 660      1.65    66.0           aquatics     0       0       0
# 663      1.72    67.0           handball     0       0       0
# 664      1.76    71.0              canoe     0       0       0
# ...       ...     ...                ...   ...     ...     ...
# 10457    1.88    82.0             tennis     0       0       0
# 10465    1.80    90.0               judo     0       0       0
# 10675    1.86    80.0           football     1       0       0
# 10709    1.87    84.0              canoe     0       0       0
# 10715     NaN     NaN           football     0       0       0
# 10749    1.78    68.0          athletics     0       0       0
# 10750    1.70    57.0             rowing     0       0       0
# 10778    1.82    58.0          taekwondo     0       0       0
# 10813    1.74    81.0               judo     0       0       0
# 10816    1.76    78.0           aquatics     0       0       0
# 10822    1.62    48.0               golf     0       0       0
# 10879    1.83    82.0           aquatics     0       0       0
# 10880    1.88   110.0           handball     0       0       0
# 10898    1.90    88.0         basketball     0       0       0
# 10899    1.85    74.0          athletics     0       0       0
# 10900    1.70    60.0          athletics     0       0       0
# 10905    1.76    67.0           aquatics     0       0       0
# 10941    1.87   100.0          athletics     0       0       0
# 10944    1.88    75.0           football     1       0       0
# 10948    1.98    87.0         volleyball     1       0       0
# 10972    1.60    85.0      weightlifting     0       0       0
# 10992    1.86    75.0           football     1       0       0
# 11010    1.71    65.0           football     1       0       0
# 11011    1.85    78.0         volleyball     1       0       0
# 11021    1.93    73.0             rowing     0       0       0
# 11052    1.78    71.0             rowing     0       0       0
# 11136    1.66    55.0  modern pentathlon     0       0       0
# 11228    1.83    78.0          badminton     0       0       0
# 11404    1.78    76.0             hockey     0       0       0
# 11457    1.70    69.0           football     1       0       0
#
# [485 rows x 11 columns]

# %% [markdown]
# ## Questão 1
#
# Considerando uma amostra de tamanho 3000 da coluna `height` obtida com a função `get_sample()`, execute o teste de normalidade de Shapiro-Wilk com a função `scipy.stats.shapiro()`. Podemos afirmar que as alturas são normalmente distribuídas com base nesse teste (ao nível de significância de 5%)? Responda com um boolean (`True` ou `False`).

# %%
def q1():
    # Retorne aqui o resultado da questão 1.
    altura = get_sample(athletes,'height', n=3000)
    shapiro_value, shapiro_p_valor = sct.shapiro(altura)
    return shapiro_p_valor>0.05
# Out:
# False

# %% [markdown]
# __Para refletir__:
#
# * Plote o histograma dessa variável (com, por exemplo, `bins=25`). A forma do gráfico e o resultado do teste são condizentes? Por que?
# * Plote o qq-plot para essa variável e a analise.
# * Existe algum nível de significância razoável que nos dê outro resultado no teste? (Não faça isso na prática. Isso é chamado _p-value hacking_, e não é legal).

# %%
altura.plot(kind='hist', bins=25);

# %% [markdown]
# ## Questão 2
#
# Repita o mesmo procedimento acima, mas agora utilizando o teste de normalidade de Jarque-Bera através da função `scipy.stats.jarque_bera()`. Agora podemos afirmar que as alturas são normalmente distribuídas (ao nível de significância de 5%)? Responda com um boolean (`True` ou `False`).

# %%
def q2():
    # Retorne aqui o resultado da questão 2.
    resultado = sct.jarque_bera(altura)
    return resultado[1]>0.05
# Out:
# False

# %% [markdown]
# __Para refletir__:
#
# * Esse resultado faz sentido?

# %% [markdown]
# ## Questão 3
#
# Considerando agora uma amostra de tamanho 3000 da coluna `weight` obtida com a função `get_sample()`. Faça o teste de normalidade de D'Agostino-Pearson utilizando a função `scipy.stats.normaltest()`. Podemos afirmar que os pesos vêm de uma distribuição normal ao nível de significância de 5%? Responda com um boolean (`True` ou `False`).

# %%
def q3():
    # Retorne aqui o resultado da questão 3.
    peso = get_sample(athletes, ['weight'], n=3000)
    th = sct.normaltest(peso)
    return th[1]>0.05

# %% [markdown]
# __Para refletir__:
#
# * Plote o histograma dessa variável (com, por exemplo, `bins=25`). A forma do gráfico e o resultado do teste são condizentes? Por que?
# * Um _box plot_ também poderia ajudar a entender a resposta.

# %%
peso.plot(kind='hist', bins=25)

# %% [markdown]
# ## Questão 4
#
# Realize uma transformação logarítmica em na amostra de `weight` da questão 3 e repita o mesmo procedimento. Podemos afirmar a normalidade da variável transformada ao nível de significância de 5%? Responda com um boolean (`True` ou `False`).

# %%
def q4():
    # Retorne aqui o resultado da questão 4.
    log_peso = np.log(peso)
    th = sct.normaltest(log_peso)
    return th[1]>0.05

# %% [markdown]
# __Para refletir__:
#
# * Plote o histograma dessa variável (com, por exemplo, `bins=25`). A forma do gráfico e o resultado do teste são condizentes? Por que?
# * Você esperava um resultado diferente agora?

# %%
log_peso.plot(kind='hist', bins=25)

# %% [markdown]
# > __Para as questão 5 6 e 7 a seguir considere todos testes efetuados ao nível de significância de 5%__.

# %% [markdown]
# ## Questão 5
#
# Obtenha todos atletas brasileiros, norte-americanos e canadenses em `DataFrame`s chamados `bra`, `usa` e `can`,respectivamente. Realize um teste de hipóteses para comparação das médias das alturas (`height`) para amostras independentes e variâncias diferentes com a função `scipy.stats.ttest_ind()` entre `bra` e `usa`. Podemos afirmar que as médias são estatisticamente iguais? Responda com um boolean (`True` ou `False`).

# %%
bra = athletes[athletes['nationality'] == 'BRA']['height'].dropna()
usa = athletes[athletes['nationality'] == 'USA']['height'].dropna()
can = athletes[athletes['nationality'] == 'CAN']['height'].dropna()

# %%
def q5():
    # Retorne aqui o resultado da questão 5.
    resultado = sct.ttest_ind(bra, usa)
    return resultado[1]>0.025
# Out:
# False

# %% [markdown]
# ## Questão 6
#
# Repita o procedimento da questão 5, mas agora entre as alturas de `bra` e `can`. Podemos afimar agora que as médias são estatisticamente iguais? Reponda com um boolean (`True` ou `False`).

# %%
def q6():
    # Retorne aqui o resultado da questão 6.
    resultado = sct.ttest_ind(bra, can)
    return resultado[1]>0.025
# Out:
# True

# %% [markdown]
# ## Questão 7
#
# Repita o procedimento da questão 6, mas agora entre as alturas de `usa` e `can`. Qual o valor do p-valor retornado? Responda como um único escalar arredondado para oito casas decimais.

# %%
def q7():
    # Retorne aqui o resultado da questão 7.
    resultado = sct.ttest_ind(usa, can, equal_var=False)
    return np.round(resultado[1], 8)
q7()
# Out:
# 0.00046601

# %% [markdown]
# __Para refletir__:
#
# * O resultado faz sentido?
# * Você consegue interpretar esse p-valor?
# * Você consegue chegar a esse valor de p-valor a partir da variável de estatística?
